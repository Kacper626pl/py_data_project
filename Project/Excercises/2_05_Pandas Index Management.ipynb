# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/2_05_Pandas Index Management.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# ## 🟩 Set Index and Display Rows (2.5.1)

# %%
df_new = df.copy()
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785736   Pekerjaan tetap               False             Singapore
# 785737   Pekerjaan tetap               False               Germany
# 785738   Pekerjaan tetap               False              Malaysia
# 785739   Pekerjaan tetap               False                 Sudan
# 785740   Pekerjaan tetap               False                 India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0      2023-06-16 13:44:15                  False                 False
# 1      2023-01-14 13:18:07                  False                 False
# 2      2023-10-10 13:14:55                  False                 False
# 3      2023-07-04 13:01:41                   True                 False
# 4      2023-08-07 14:29:36                  False                 False
# ...                    ...                    ...                   ...
# 785736 2023-03-13 06:16:16                  False                 False
# 785737 2023-03-12 06:18:18                  False                 False
# 785738 2023-03-12 06:32:36                  False                 False
# 785739 2023-03-12 06:32:15                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States        None              NaN              NaN
# 1              Mexico        None              NaN              NaN
# 2             Germany        None              NaN              NaN
# 3       United States        None              NaN              NaN
# 4               Sudan        None              NaN              NaN
# ...               ...         ...              ...              ...
# 785736      Singapore        None              NaN              NaN
# 785737        Germany        None              NaN              NaN
# 785738       Malaysia        None              NaN              NaN
# 785739          Sudan        None              NaN              NaN
# 785740          India        None              NaN              NaN
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 0                                                    None
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 0                                                    None
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                   ...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}
#
# [785741 rows x 17 columns]

# %%
df_new.set_index('salary_year_avg', inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Reset Index and Drop Existing (2.5.2)

# %%
df_new.sort_index()
# Out:
#                  level_0   index  \
# salary_year_avg
# 15000.0           665729  665729
# 16500.0           380187  380187
# 20000.0           130855  130855
# 23496.0           535260  535260
# 24000.0           213687  213687
# ...                  ...     ...
# NaN               785736  785736
# NaN               785737  785737
# NaN               785738  785738
# NaN               785739  785739
# NaN               785740  785740
#
#                                                          job_title  \
# salary_year_avg
# 15000.0                                     Data Engineer - Hadoop
# 16500.0                                         Operations Analyst
# 20000.0                            Showwcase Elite - Data Engineer
# 23496.0                                         Lead Data Engineer
# 24000.0          Data Engineer Jobs In Flipdish for Engineering...
# ...                                                            ...
# NaN                                                DevOps Engineer
# NaN                                               CRM Data Analyst
# NaN                                 Commercial Analyst - Start Now
# NaN              Principal Associate, Data Engineer (Remote-Eli...
# NaN                                             AWS System Analyst
#
#                                         job_location  \
# salary_year_avg
# 15000.0                                       Brazil
# 16500.0                                     Anywhere
# 20000.0                                     Anywhere
# 23496.0                              Kansas City, MO
# 24000.0                            Karachi, Pakistan
# ...                                              ...
# NaN                                        Singapura
# NaN                               Bad Rodach, Jerman
# NaN                                         Malaysia
# NaN              Newark, New Jersey, Amerika Serikat
# NaN                                            India
#
#                                               job_via job_schedule_type  \
# salary_year_avg
# 15000.0                                  via LinkedIn         Full-time
# 16500.0                                 via Wellfound         Full-time
# 20000.0                                 via Wellfound         Full-time
# 23496.0                                    via Adzuna         Full-time
# 24000.0          via Get Daily Fresh Jobs Opportunity         Full-time
# ...                                               ...               ...
# NaN                               melalui Trabajo.org   Pekerjaan tetap
# NaN                         melalui BeBee Deutschland   Pekerjaan tetap
# NaN                                  melalui Ricebowl   Pekerjaan tetap
# NaN                               melalui Recruit.net   Pekerjaan tetap
# NaN                                    melalui Trigyn   Pekerjaan tetap
#
#                  job_work_from_home         search_location  \
# salary_year_avg
# 15000.0                       False                  Brazil
# 16500.0                        True              Bangladesh
# 20000.0                        True               Australia
# 23496.0                       False  Florida, United States
# 24000.0                       False                Pakistan
# ...                             ...                     ...
# NaN                           False               Singapore
# NaN                           False                 Germany
# NaN                           False                Malaysia
# NaN                           False                   Sudan
# NaN                           False                   India
#
#                     job_posted_date  job_no_degree_mention  \
# salary_year_avg
# 15000.0         2023-12-09 10:05:30                   True
# 16500.0         2023-05-16 18:39:05                  False
# 20000.0         2023-07-07 08:20:46                  False
# 23496.0         2023-02-11 19:12:33                  False
# 24000.0         2023-09-23 22:28:39                  False
# ...                             ...                    ...
# NaN             2023-03-13 06:16:16                  False
# NaN             2023-03-12 06:18:18                  False
# NaN             2023-03-12 06:32:36                  False
# NaN             2023-03-12 06:32:15                  False
# NaN             2023-03-13 06:16:31                  False
#
#                  job_health_insurance    job_country salary_rate  \
# salary_year_avg
# 15000.0                         False         Brazil        year
# 16500.0                         False     Bangladesh        year
# 20000.0                         False      Australia        year
# 23496.0                         False  United States        year
# 24000.0                         False       Pakistan        year
# ...                               ...            ...         ...
# NaN                             False      Singapore        None
# NaN                             False        Germany        None
# NaN                             False       Malaysia        None
# NaN                             False          Sudan        None
# NaN                             False          India        None
#
#                  salary_hour_avg                        company_name  \
# salary_year_avg
# 15000.0                      NaN                     Net2Source Inc.
# 16500.0                      NaN                             Forward
# 20000.0                      NaN                           Showwcase
# 23496.0                      NaN        American Century Investments
# 24000.0                      NaN                            Flipdish
# ...                          ...                                 ...
# NaN                          NaN  CAREERSTAR INTERNATIONAL PTE. LTD.
# NaN                          NaN                    HABA FAMILYGROUP
# NaN                          NaN               Lendlease Corporation
# NaN                          NaN                         Capital One
# NaN                          NaN                              Trigyn
#
#                                                         job_skills  \
# salary_year_avg
# 15000.0          ['java', 'python', 'oracle', 'aws', 'hadoop', ...
# 16500.0                                                       None
# 20000.0          ['go', 'sql', 'python', 'react', 'flutter', 'a...
# 23496.0          ['python', 'java', 'r', 'sas', 'sas', 'mysql',...
# 24000.0          ['python', 'java', 'scala', 'sql', 'nosql', 'h...
# ...                                                            ...
# NaN              ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# NaN                                 ['sas', 'sas', 'sql', 'excel']
# NaN                                        ['powerpoint', 'excel']
# NaN              ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# NaN                                                ['aws', 'flow']
#
#                                                    job_type_skills
# salary_year_avg
# 15000.0          {'cloud': ['oracle', 'aws'], 'libraries': ['ha...
# 16500.0                                                       None
# 20000.0          {'libraries': ['react', 'flutter', 'airflow'],...
# 23496.0          {'analyst_tools': ['sas', 'ssis', 'tableau'], ...
# 24000.0          {'analyst_tools': ['excel'], 'libraries': ['ha...
# ...                                                            ...
# NaN              {'os': ['linux', 'unix'], 'other': ['kubernete...
# NaN              {'analyst_tools': ['sas', 'excel'], 'programmi...
# NaN                     {'analyst_tools': ['powerpoint', 'excel']}
# NaN              {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# NaN                          {'cloud': ['aws'], 'other': ['flow']}
#
# [785741 rows x 17 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Sort Index (2.5.3)

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Pivot Table Reset & Set Index (2.5.4)

# %%
df_new.pivot_table()

# %% [markdown]
# ---
